# %%
# !pip install wikidata
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wikidata
#   Downloading Wikidata-0.7.0-py3-none-any.whl (29 kB)
# Installing collected packages: wikidata
# Successfully installed wikidata-0.7.0

# %%
# !pip install --upgrade openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.2-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 KB 508.8 kB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->openai) (22.2.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 7.9 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 2.2 MB/s eta 0:00:00
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.2 yarl-1.8.2

# %%
from wikidata.client import Client
import os
import openai
import pandas as pd
import spacy
import re
import random

nlp = spacy.load("en_core_web_sm")
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
openai.api_key = "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"

# %%
client = Client()

# %% [markdown]
# Test Run with Test Categories

# %%
def get_correct_article(text):
    ## simple logic to make articles match their targets
    if text[0].lower() in ['a', 'e', 'i', 'o', 'u']:
      article_variant = "an"
    else:
      article_variant = "a"
    
    return article_variant

# %%
def setSubsetQuestion(index):
  
  article_variant = get_correct_article(df.loc[index, 'classLabel.value'])

  ## should we inject quotes around the itemLabel.value 
  query_basic = f"True or false: {df.loc[index, 'itemLabel.value']} is {article_variant} {df.loc[index, 'classLabel.value']}"
  df.loc[index, 'set_subset_q'] = query_basic
  print(query_basic)
  response_basic = openai.Completion.create(model="text-davinci-003", prompt=query_basic, temperature=0, max_tokens=1000)
  df.loc[index, 'set_subset_a'] = response_basic['choices'][0]['text']
  print(response_basic['choices'][0]['text'])

  return

# %%
def falsePresuppositionQuestion(random_index):

  article_variant = get_correct_article(df.loc[index, 'classLabel.value'])

  query_false_presupposition = f"Why isn't {df.loc[index, 'itemLabel.value']} {article_variant} {df.loc[index, 'classLabel.value']}?"
  df.loc[index, 'false_presup_q'] = query_false_presupposition
  print(query_false_presupposition)
  response_false_presupposition = openai.Completion.create(model="text-davinci-003", prompt=query_false_presupposition, temperature=0, max_tokens=1000)
  df.loc[index, 'false_presup_a'] = response_false_presupposition['choices'][0]['text']
  print(response_false_presupposition['choices'][0]['text'])

  return

# %%
df = pd.read_csv('wikidata_sample_df.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-ebbc83160151> in <module>
# ----> 1 df = pd.read_csv('data/wikidata_sample_df.csv', index_col=0)
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# /usr/local/lib/python3.9/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/wikidata_sample_df.csv'

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head()
# Out:
#   item.type                             item.value class.type  \
# 0       uri  http://www.wikidata.org/entity/Q27143        uri
# 1       uri  http://www.wikidata.org/entity/Q27143        uri
# 2       uri  http://www.wikidata.org/entity/Q27143        uri
# 3       uri  http://www.wikidata.org/entity/Q38441        uri
# 4       uri  http://www.wikidata.org/entity/Q42816        uri
#
#                                class.value itemLabel.xml:lang itemLabel.type  \
# 0   http://www.wikidata.org/entity/Q786820                 en        literal
# 1   http://www.wikidata.org/entity/Q936518                 en        literal
# 2  http://www.wikidata.org/entity/Q6881511                 en        literal
# 3    http://www.wikidata.org/entity/Q34038                 en        literal
# 4   http://www.wikidata.org/entity/Q747074                 en        literal
#
#     itemLabel.value classLabel.xml:lang classLabel.type  \
# 0              Avia                  en         literal
# 1              Avia                  en         literal
# 2              Avia                  en         literal
# 3  Steall Waterfall                  en         literal
# 4   Corte de' Frati                  en         literal
#
#           classLabel.value  subclass.type  subclass.value  \
# 0  automobile manufacturer            NaN             NaN
# 1   aerospace manufacturer            NaN             NaN
# 2               enterprise            NaN             NaN
# 3                waterfall            NaN             NaN
# 4          comune of Italy            NaN             NaN
#
#    subclassLabel.xml:lang  subclassLabel.type  subclassLabel.value
# 0                     NaN                 NaN                  NaN
# 1                     NaN                 NaN                  NaN
# 2                     NaN                 NaN                  NaN
# 3                     NaN                 NaN                  NaN
# 4                     NaN                 NaN                  NaN

# %%
df['set_subset_q'] = ''
df['set_subset_a'] = ''
df['false_presup_q'] = ''
df['false_presup_a'] = ''

# %%
df.head()
# Out:
#   item.type                             item.value class.type  \
# 0       uri  http://www.wikidata.org/entity/Q27143        uri
# 1       uri  http://www.wikidata.org/entity/Q27143        uri
# 2       uri  http://www.wikidata.org/entity/Q27143        uri
# 3       uri  http://www.wikidata.org/entity/Q38441        uri
# 4       uri  http://www.wikidata.org/entity/Q42816        uri
#
#                                class.value itemLabel.xml:lang itemLabel.type  \
# 0   http://www.wikidata.org/entity/Q786820                 en        literal
# 1   http://www.wikidata.org/entity/Q936518                 en        literal
# 2  http://www.wikidata.org/entity/Q6881511                 en        literal
# 3    http://www.wikidata.org/entity/Q34038                 en        literal
# 4   http://www.wikidata.org/entity/Q747074                 en        literal
#
#     itemLabel.value classLabel.xml:lang classLabel.type  \
# 0              Avia                  en         literal
# 1              Avia                  en         literal
# 2              Avia                  en         literal
# 3  Steall Waterfall                  en         literal
# 4   Corte de' Frati                  en         literal
#
#           classLabel.value  subclass.type  subclass.value  \
# 0  automobile manufacturer            NaN             NaN
# 1   aerospace manufacturer            NaN             NaN
# 2               enterprise            NaN             NaN
# 3                waterfall            NaN             NaN
# 4          comune of Italy            NaN             NaN
#
#    subclassLabel.xml:lang  subclassLabel.type  subclassLabel.value  \
# 0                     NaN                 NaN                  NaN
# 1                     NaN                 NaN                  NaN
# 2                     NaN                 NaN                  NaN
# 3                     NaN                 NaN                  NaN
# 4                     NaN                 NaN                  NaN
#
#   set_subset_q set_subset_a false_presup_q false_presup_a
# 0
# 1
# 2
# 3
# 4

# %%
#df.loc[0, 'set_subset_q'] = 'test'

# %%
cats = ['human','album','village','film','river','asteroid','musical group','literary work','chemical compound']

for cat in cats:

  df_cat = df[df['classLabel.value']==cat].reset_index(drop=False)

  for i in range(1):

    random_index = random.randrange(df_cat.shape[0])
    index = df_cat.loc[random_index, 'index']
    print(index)
    print(df.iloc[index])
    #print(df_cat.loc[random_index, 'index'])
    setSubsetQuestion(index)
    print(df.iloc[index])
# Out:
# 5398
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q4958435
# class.type                                                    uri
# class.value                     http://www.wikidata.org/entity/Q5
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                   Gillian Kearney
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                            human
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 5398, dtype: object
# True or false: Gillian Kearney is a human
#
#
# True
# item.type                                                       uri
# item.value                  http://www.wikidata.org/entity/Q4958435
# class.type                                                      uri
# class.value                       http://www.wikidata.org/entity/Q5
# itemLabel.xml:lang                                               en
# itemLabel.type                                              literal
# itemLabel.value                                     Gillian Kearney
# classLabel.xml:lang                                              en
# classLabel.type                                             literal
# classLabel.value                                              human
# subclass.type                                                   NaN
# subclass.value                                                  NaN
# subclassLabel.xml:lang                                          NaN
# subclassLabel.type                                              NaN
# subclassLabel.value                                             NaN
# set_subset_q              True or false: Gillian Kearney is a human
# set_subset_a                                               \n\nTrue
# false_presup_q
# false_presup_a
# Name: 5398, dtype: object
# 68696
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q7270390
# class.type                                                    uri
# class.value                http://www.wikidata.org/entity/Q482994
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                       Queen Elvis
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                            album
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 68696, dtype: object
# True or false: Queen Elvis is a album
#  by Elvis Presley
#
# False
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q7270390
# class.type                                                    uri
# class.value                http://www.wikidata.org/entity/Q482994
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                       Queen Elvis
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                            album
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q                True or false: Queen Elvis is a album
# set_subset_a                            by Elvis Presley\n\nFalse
# false_presup_q
# false_presup_a
# Name: 68696, dtype: object
# 47026
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q5663386
# class.type                                                    uri
# class.value                   http://www.wikidata.org/entity/Q532
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                   Babuneh-ye Olya
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                          village
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 47026, dtype: object
# True or false: Babuneh-ye Olya is a village
#  in Iran
#
# True
# item.type                                                         uri
# item.value                    http://www.wikidata.org/entity/Q5663386
# class.type                                                        uri
# class.value                       http://www.wikidata.org/entity/Q532
# itemLabel.xml:lang                                                 en
# itemLabel.type                                                literal
# itemLabel.value                                       Babuneh-ye Olya
# classLabel.xml:lang                                                en
# classLabel.type                                               literal
# classLabel.value                                              village
# subclass.type                                                     NaN
# subclass.value                                                    NaN
# subclassLabel.xml:lang                                            NaN
# subclassLabel.type                                                NaN
# subclassLabel.value                                               NaN
# set_subset_q              True or false: Babuneh-ye Olya is a village
# set_subset_a                                          in Iran\n\nTrue
# false_presup_q
# false_presup_a
# Name: 47026, dtype: object
# 23863
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q5303318
# class.type                                                    uri
# class.value                 http://www.wikidata.org/entity/Q11424
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                          Downtime
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                             film
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 23863, dtype: object
# True or false: Downtime is a film
#
#
# False
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q5303318
# class.type                                                    uri
# class.value                 http://www.wikidata.org/entity/Q11424
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                          Downtime
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                             film
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q                    True or false: Downtime is a film
# set_subset_a                                            \n\nFalse
# false_presup_q
# false_presup_a
# Name: 23863, dtype: object
# 7455
# item.type                                                    uri
# item.value                http://www.wikidata.org/entity/Q430473
# class.type                                                   uri
# class.value                 http://www.wikidata.org/entity/Q4022
# itemLabel.xml:lang                                            en
# itemLabel.type                                           literal
# itemLabel.value                                   Kočanska River
# classLabel.xml:lang                                           en
# classLabel.type                                          literal
# classLabel.value                                           river
# subclass.type                                                NaN
# subclass.value                                               NaN
# subclassLabel.xml:lang                                       NaN
# subclassLabel.type                                           NaN
# subclassLabel.value                                          NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 7455, dtype: object
# True or false: Kočanska River is a river
#  in Serbia
#
# False
# item.type                                                      uri
# item.value                  http://www.wikidata.org/entity/Q430473
# class.type                                                     uri
# class.value                   http://www.wikidata.org/entity/Q4022
# itemLabel.xml:lang                                              en
# itemLabel.type                                             literal
# itemLabel.value                                     Kočanska River
# classLabel.xml:lang                                             en
# classLabel.type                                            literal
# classLabel.value                                             river
# subclass.type                                                  NaN
# subclass.value                                                 NaN
# subclassLabel.xml:lang                                         NaN
# subclassLabel.type                                             NaN
# subclassLabel.value                                            NaN
# set_subset_q              True or false: Kočanska River is a river
# set_subset_a                                    in Serbia\n\nFalse
# false_presup_q
# false_presup_a
# Name: 7455, dtype: object
# 12389
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q5333867
# class.type                                                    uri
# class.value                  http://www.wikidata.org/entity/Q3863
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                  (22377) 1993 UW6
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                         asteroid
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 12389, dtype: object
# True or false: (22377) 1993 UW6 is a asteroid
#
#
# False, (22377) 1993 UW6 is a comet.
# item.type                                                           uri
# item.value                      http://www.wikidata.org/entity/Q5333867
# class.type                                                          uri
# class.value                        http://www.wikidata.org/entity/Q3863
# itemLabel.xml:lang                                                   en
# itemLabel.type                                                  literal
# itemLabel.value                                        (22377) 1993 UW6
# classLabel.xml:lang                                                  en
# classLabel.type                                                 literal
# classLabel.value                                               asteroid
# subclass.type                                                       NaN
# subclass.value                                                      NaN
# subclassLabel.xml:lang                                              NaN
# subclassLabel.type                                                  NaN
# subclassLabel.value                                                 NaN
# set_subset_q              True or false: (22377) 1993 UW6 is a asteroid
# set_subset_a                    \n\nFalse, (22377) 1993 UW6 is a comet.
# false_presup_q
# false_presup_a
# Name: 12389, dtype: object
# 20084
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q4879523
# class.type                                                    uri
# class.value                http://www.wikidata.org/entity/Q215380
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                    Bee and Flower
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                    musical group
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 20084, dtype: object
# True or false: Bee and Flower is a musical group
#
#
# False
# item.type                                                              uri
# item.value                         http://www.wikidata.org/entity/Q4879523
# class.type                                                             uri
# class.value                         http://www.wikidata.org/entity/Q215380
# itemLabel.xml:lang                                                      en
# itemLabel.type                                                     literal
# itemLabel.value                                             Bee and Flower
# classLabel.xml:lang                                                     en
# classLabel.type                                                    literal
# classLabel.value                                             musical group
# subclass.type                                                          NaN
# subclass.value                                                         NaN
# subclassLabel.xml:lang                                                 NaN
# subclassLabel.type                                                     NaN
# subclassLabel.value                                                    NaN
# set_subset_q              True or false: Bee and Flower is a musical group
# set_subset_a                                                     \n\nFalse
# false_presup_q
# false_presup_a
# Name: 20084, dtype: object
# 9858
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q5986646
# class.type                                                    uri
# class.value               http://www.wikidata.org/entity/Q7725634
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                      Icon of Evil
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                    literary work
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 9858, dtype: object
# True or false: Icon of Evil is a literary work
#
#
# False
# item.type                                                            uri
# item.value                       http://www.wikidata.org/entity/Q5986646
# class.type                                                           uri
# class.value                      http://www.wikidata.org/entity/Q7725634
# itemLabel.xml:lang                                                    en
# itemLabel.type                                                   literal
# itemLabel.value                                             Icon of Evil
# classLabel.xml:lang                                                   en
# classLabel.type                                                  literal
# classLabel.value                                           literary work
# subclass.type                                                        NaN
# subclass.value                                                       NaN
# subclassLabel.xml:lang                                               NaN
# subclassLabel.type                                                   NaN
# subclassLabel.value                                                  NaN
# set_subset_q              True or false: Icon of Evil is a literary work
# set_subset_a                                                   \n\nFalse
# false_presup_q
# false_presup_a
# Name: 9858, dtype: object
# 44216
# item.type                                                    uri
# item.value                http://www.wikidata.org/entity/Q300902
# class.type                                                   uri
# class.value                http://www.wikidata.org/entity/Q11173
# itemLabel.xml:lang                                            en
# itemLabel.type                                           literal
# itemLabel.value                    tris(2-carboxyethyl)phosphine
# classLabel.xml:lang                                           en
# classLabel.type                                          literal
# classLabel.value                               chemical compound
# subclass.type                                                NaN
# subclass.value                                               NaN
# subclassLabel.xml:lang                                       NaN
# subclassLabel.type                                           NaN
# subclassLabel.value                                          NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 44216, dtype: object
# True or false: tris(2-carboxyethyl)phosphine is a chemical compound
#
#
# True
# item.type                                                               uri
# item.value                           http://www.wikidata.org/entity/Q300902
# class.type                                                              uri
# class.value                           http://www.wikidata.org/entity/Q11173
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                               tris(2-carboxyethyl)phosphine
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                          chemical compound
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q              True or false: tris(2-carboxyethyl)phosphine i...
# set_subset_a                                                       \n\nTrue
# false_presup_q
# false_presup_a
# Name: 44216, dtype: object

# %%
df.loc[87399, 'set_subset_q']
# Out:
# 'True or false: Cake & Ice Cream is a album'

# %%
df.loc[87399, 'set_subset_a']
# Out:
# ' by the band The Beatles\n\nFalse'

# %%
cats = ['human','album','village','film','river','asteroid','musical group','literary work','chemical compound']

for cat in cats:

  df_cat = df[df['classLabel.value']==cat].reset_index(drop=False)

  for i in range(1):

    random_index = random.randrange(df_cat.shape[0])
    index = df_cat.loc[random_index, 'index']
    print(index)
    print(df.iloc[index])
    #print(df_cat.loc[random_index, 'index'])
    falsePresuppositionQuestion(index)
    print(df.iloc[index])
# Out:
# 57948
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q5438990
# class.type                                                    uri
# class.value                     http://www.wikidata.org/entity/Q5
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                  Faye Throneberry
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                            human
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 57948, dtype: object
# Why isn't Faye Throneberry a human?
#
#
# Faye Throneberry is not a human because she is a fictional character created for the television show My Three Sons. She was portrayed by actress Beverly Washburn.
# item.type                                                               uri
# item.value                          http://www.wikidata.org/entity/Q5438990
# class.type                                                              uri
# class.value                               http://www.wikidata.org/entity/Q5
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                            Faye Throneberry
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                                      human
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q                          Why isn't Faye Throneberry a human?
# false_presup_a            \n\nFaye Throneberry is not a human because sh...
# Name: 57948, dtype: object
# 77458
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q7111786
# class.type                                                    uri
# class.value                http://www.wikidata.org/entity/Q482994
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                Out of the Shadows
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                            album
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 77458, dtype: object
# Why isn't Out of the Shadows a album?
#
#
# Out of the Shadows is not an album because it is a song by the band The Shadows. It was released as a single in 1962 and was later included on the compilation album The Shadows Greatest Hits.
# item.type                                                               uri
# item.value                          http://www.wikidata.org/entity/Q7111786
# class.type                                                              uri
# class.value                          http://www.wikidata.org/entity/Q482994
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                          Out of the Shadows
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                                      album
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q                        Why isn't Out of the Shadows a album?
# false_presup_a            \n\nOut of the Shadows is not an album because...
# Name: 77458, dtype: object
# 27232
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q6865608
# class.type                                                    uri
# class.value                   http://www.wikidata.org/entity/Q532
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                           Ballıca
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                          village
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 27232, dtype: object
# Why isn't Ballıca a village?
#
#
# Ballıca is not a village because it is a neighborhood in the city of Istanbul, Turkey. It is located in the district of Beykoz, on the Asian side of the city.
# item.type                                                               uri
# item.value                          http://www.wikidata.org/entity/Q6865608
# class.type                                                              uri
# class.value                             http://www.wikidata.org/entity/Q532
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                                     Ballıca
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                                    village
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q                                 Why isn't Ballıca a village?
# false_presup_a            \n\nBallıca is not a village because it is a n...
# Name: 27232, dtype: object
# 10397
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q1456054
# class.type                                                    uri
# class.value                 http://www.wikidata.org/entity/Q11424
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                         Blindfold
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                             film
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 10397, dtype: object
# Why isn't Blindfold a film?
#
#
# Blindfold is not a film because it is a novel written by Lois Duncan. It was published in 1966 and has not been adapted into a film.
# item.type                                                               uri
# item.value                          http://www.wikidata.org/entity/Q1456054
# class.type                                                              uri
# class.value                           http://www.wikidata.org/entity/Q11424
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                                   Blindfold
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                                       film
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q                                  Why isn't Blindfold a film?
# false_presup_a            \n\nBlindfold is not a film because it is a no...
# Name: 10397, dtype: object
# 136829
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q4522587
# class.type                                                    uri
# class.value                  http://www.wikidata.org/entity/Q4022
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                          Sheleksa
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                            river
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 136829, dtype: object
# Why isn't Sheleksa a river?
#
#
# Sheleksa is not a river because it is a town in the Krasnodar Krai region of Russia. It is located on the left bank of the Sheksna River.
# item.type                                                               uri
# item.value                          http://www.wikidata.org/entity/Q4522587
# class.type                                                              uri
# class.value                            http://www.wikidata.org/entity/Q4022
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                                    Sheleksa
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                                      river
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q                                  Why isn't Sheleksa a river?
# false_presup_a            \n\nSheleksa is not a river because it is a to...
# Name: 136829, dtype: object
# 41685
# item.type                                                    uri
# item.value                http://www.wikidata.org/entity/Q937775
# class.type                                                   uri
# class.value                 http://www.wikidata.org/entity/Q3863
# itemLabel.xml:lang                                            en
# itemLabel.type                                           literal
# itemLabel.value                                     5500 Twilley
# classLabel.xml:lang                                           en
# classLabel.type                                          literal
# classLabel.value                                        asteroid
# subclass.type                                                NaN
# subclass.value                                               NaN
# subclassLabel.xml:lang                                       NaN
# subclassLabel.type                                           NaN
# subclassLabel.value                                          NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 41685, dtype: object
# Why isn't 5500 Twilley a asteroid?
#
#
# Asteroids are small, rocky objects that orbit the Sun. They are much smaller than planets and are usually found in the asteroid belt between Mars and Jupiter. 5500 Twilley is not an asteroid because it is a main-belt comet, which is a type of comet that orbits the Sun in the main asteroid belt.
# item.type                                                               uri
# item.value                           http://www.wikidata.org/entity/Q937775
# class.type                                                              uri
# class.value                            http://www.wikidata.org/entity/Q3863
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                                5500 Twilley
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                                   asteroid
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q                           Why isn't 5500 Twilley a asteroid?
# false_presup_a            \n\nAsteroids are small, rocky objects that or...
# Name: 41685, dtype: object
# 57157
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q4200176
# class.type                                                    uri
# class.value                http://www.wikidata.org/entity/Q215380
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                          ADA Band
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                    musical group
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 57157, dtype: object
# Why isn't ADA Band a musical group?
#
#
# ADA Band is not a musical group; it is a brand of musical instruments and accessories.
# item.type                                                               uri
# item.value                          http://www.wikidata.org/entity/Q4200176
# class.type                                                              uri
# class.value                          http://www.wikidata.org/entity/Q215380
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                                    ADA Band
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                              musical group
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q                          Why isn't ADA Band a musical group?
# false_presup_a            \n\nADA Band is not a musical group; it is a b...
# Name: 57157, dtype: object
# 128578
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q7742029
# class.type                                                    uri
# class.value               http://www.wikidata.org/entity/Q7725634
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                                   The Inheritance
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                    literary work
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 128578, dtype: object
# Why isn't The Inheritance a literary work?
#
#
# The Inheritance is not a literary work because it is a play written by Matthew Lopez. Literary works are typically written in prose or poetry, and plays are not considered to be literary works.
# item.type                                                               uri
# item.value                          http://www.wikidata.org/entity/Q7742029
# class.type                                                              uri
# class.value                         http://www.wikidata.org/entity/Q7725634
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                             The Inheritance
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                              literary work
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q                   Why isn't The Inheritance a literary work?
# false_presup_a            \n\nThe Inheritance is not a literary work bec...
# Name: 128578, dtype: object
# 122402
# item.type                                                     uri
# item.value                http://www.wikidata.org/entity/Q2757969
# class.type                                                    uri
# class.value                 http://www.wikidata.org/entity/Q11173
# itemLabel.xml:lang                                             en
# itemLabel.type                                            literal
# itemLabel.value                             meglumine antimoniate
# classLabel.xml:lang                                            en
# classLabel.type                                           literal
# classLabel.value                                chemical compound
# subclass.type                                                 NaN
# subclass.value                                                NaN
# subclassLabel.xml:lang                                        NaN
# subclassLabel.type                                            NaN
# subclassLabel.value                                           NaN
# set_subset_q
# set_subset_a
# false_presup_q
# false_presup_a
# Name: 122402, dtype: object
# Why isn't meglumine antimoniate a chemical compound?
#
#
# Meglumine antimoniate is not a chemical compound because it is a combination of two different compounds, meglumine and antimony trioxide. Meglumine is a polyethylene glycol derivative, and antimony trioxide is an inorganic compound.
# item.type                                                               uri
# item.value                          http://www.wikidata.org/entity/Q2757969
# class.type                                                              uri
# class.value                           http://www.wikidata.org/entity/Q11173
# itemLabel.xml:lang                                                       en
# itemLabel.type                                                      literal
# itemLabel.value                                       meglumine antimoniate
# classLabel.xml:lang                                                      en
# classLabel.type                                                     literal
# classLabel.value                                          chemical compound
# subclass.type                                                           NaN
# subclass.value                                                          NaN
# subclassLabel.xml:lang                                                  NaN
# subclassLabel.type                                                      NaN
# subclassLabel.value                                                     NaN
# set_subset_q
# set_subset_a
# false_presup_q            Why isn't meglumine antimoniate a chemical com...
# false_presup_a            \n\nMeglumine antimoniate is not a chemical co...
# Name: 122402, dtype: object
